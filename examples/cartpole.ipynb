# %%
# !pip install muax

# %%
import jax 
jax.config.update('jax_platform_name', 'cpu')
from jax import numpy as jnp

import gymnasium as gym

# %% [markdown]
# # 1. Use `muax.fit` to fit CartPole-v1

# %%
import muax
from muax import nn

# %% [markdown]
# `muax` provides example `representation`, `prediction` and `dynamic` modules

# %%
support_size = 10 
embedding_size = 8
discount = 0.997
num_actions = 2
full_support_size = int(support_size * 2 + 1)

repr_fn = nn._init_representation_func(nn.Representation, embedding_size)
pred_fn = nn._init_prediction_func(nn.Prediction, num_actions, full_support_size)
dy_fn = nn._init_dynamic_func(nn.Dynamic, embedding_size, num_actions, full_support_size)

# %% [markdown]
# Alternatively, you can use your customized models

# %%
import haiku as hk

class Representation(hk.Module):
  def __init__(self, embedding_dim, name='representation'):
    super().__init__(name=name)

    self.repr_func = hk.Sequential([
        hk.Linear(embedding_dim), 
        # jax.nn.elu,
    ])

  def __call__(self, obs):
    s = self.repr_func(obs)
    s = nn.min_max_normalize(s)
    return s 


class Prediction(hk.Module):
  def __init__(self, num_actions, full_support_size, name='prediction'):
    super().__init__(name=name)        
    
    self.v_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(64), jax.nn.elu,
        hk.Linear(16), jax.nn.elu,
        hk.Linear(full_support_size)
    ])
    self.pi_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(64), jax.nn.elu,
        hk.Linear(16), jax.nn.elu,
        hk.Linear(num_actions)
    ])
  
  def __call__(self, s):
    v = self.v_func(s)
    logits = self.pi_func(s)
    # logits = jax.nn.softmax(logits, axis=-1)
    return v, logits


class Dynamic(hk.Module):
  def __init__(self, embedding_dim, num_actions, full_support_size, name='dynamic'):
    super().__init__(name=name)
    
    self.ns_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(64), jax.nn.elu,
        hk.Linear(16), jax.nn.elu,
        hk.Linear(embedding_dim)
    ])
    self.r_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(64), jax.nn.elu,
        hk.Linear(16), jax.nn.elu,
        hk.Linear(full_support_size)
    ])
    self.cat_func = jax.jit(lambda s, a: 
                            jnp.concatenate([s, jax.nn.one_hot(a, num_actions)],
                                            axis=1)
                            )
  
  def __call__(self, s, a):
    sa = self.cat_func(s, a)
    r = self.r_func(sa)
    ns = self.ns_func(sa)
    ns = nn.min_max_normalize(ns)
    return r, ns


def init_representation_func(representation_module, embedding_dim):
    def representation_func(obs):
      repr_model = representation_module(embedding_dim)
      return repr_model(obs)
    return representation_func
  
def init_prediction_func(prediction_module, num_actions, full_support_size):
  def prediction_func(s):
    pred_model = prediction_module(num_actions, full_support_size)
    return pred_model(s)
  return prediction_func

def init_dynamic_func(dynamic_module, embedding_dim, num_actions, full_support_size):
  def dynamic_func(s, a):
    dy_model = dynamic_module(embedding_dim, num_actions, full_support_size)
    return dy_model(s, a)
  return dynamic_func

# %% [markdown]
# `muax` has `Episode tracer` and `replay buffuer` to track and store trajectories from interacting with environments

# %%
tracer = muax.PNStep(10, discount, 0.5)
buffer = muax.TrajectoryReplayBuffer(500)

# %% [markdown]
# `muax` leverages `optax` to update weights

# %%
gradient_transform = muax.model.optimizer(init_value=0.02, peak_value=0.02, end_value=0.0001, warmup_steps=15000, transition_steps=15000)
# gradient_transform = optax.adam(0.02)

# %%
i = 1
support_size = 20
embedding_size = 10
full_support_size = int(support_size * 2 + 1)
num_actions = 2

repr_fn = init_representation_func(Representation, embedding_size)
pred_fn = init_prediction_func(Prediction, num_actions, full_support_size)
dy_fn = init_dynamic_func(Dynamic, embedding_size, num_actions, full_support_size)

tracer = muax.PNStep(50, 0.999, 0.5)
buffer = muax.TrajectoryReplayBuffer(500)

gradient_transform = muax.model.optimizer(init_value=0.002, peak_value=0.002, end_value=0.0005, warmup_steps=20000, transition_steps=20000)

model = muax.MuZero(repr_fn, pred_fn, dy_fn, policy='muzero', discount=0.999,
                    optimizer=gradient_transform, support_size=support_size)

model_path = muax.fit(model, 'CartPole-v1', 
                max_episodes=1000,
                max_training_steps=50000,
                tracer=tracer,
                buffer=buffer,
                k_steps=10,
                sample_per_trajectory=1,
                buffer_warm_up=128,
                num_trajectory=128,
                tensorboard_dir='/tensorboard/',
                save_name='model_params',
                random_seed=i,
                log_all_metrics=True)
# Out:
# buffer warm up stage...
# start training...(E0)
# [TrainMonitor|INFO] ep: 1,	T: 12,	G: 11,	avg_r: 1,	avg_G: 11,	t: 11,	dt: 4235.846ms,	v: -0.209,	Rn: 5.98,	loss: 2,	training_step: 50,	test_G: 12
# [TrainMonitor|INFO] ep: 2,	T: 34,	G: 21,	avg_r: 1,	avg_G: 16,	t: 21,	dt: 536.228ms,	v: 8.96,	Rn: 10.9,	loss: 0.803,	training_step: 100
# [TrainMonitor|INFO] ep: 3,	T: 46,	G: 11,	avg_r: 1,	avg_G: 14.3,	t: 11,	dt: 48.624ms,	v: 12.9,	Rn: 5.98,	loss: 0.799,	training_step: 150
# [TrainMonitor|INFO] ep: 4,	T: 57,	G: 10,	avg_r: 1,	avg_G: 13.2,	t: 10,	dt: 477.752ms,	v: 7.55,	Rn: 5.48,	loss: 0.726,	training_step: 200
# [TrainMonitor|INFO] ep: 5,	T: 70,	G: 12,	avg_r: 1,	avg_G: 13,	t: 12,	dt: 43.558ms,	v: 7.99,	Rn: 6.48,	loss: 0.792,	training_step: 250
# [TrainMonitor|INFO] ep: 6,	T: 81,	G: 10,	avg_r: 1,	avg_G: 12.5,	t: 10,	dt: 50.561ms,	v: 7.13,	Rn: 5.48,	loss: 0.728,	training_step: 300
# [TrainMonitor|INFO] ep: 7,	T: 92,	G: 10,	avg_r: 1,	avg_G: 12.1,	t: 10,	dt: 256.502ms,	v: 6.76,	Rn: 5.48,	loss: 0.731,	training_step: 350
# [TrainMonitor|INFO] ep: 8,	T: 111,	G: 18,	avg_r: 1,	avg_G: 12.9,	t: 18,	dt: 27.242ms,	v: 9.26,	Rn: 9.45,	loss: 0.754,	training_step: 400
# [TrainMonitor|INFO] ep: 9,	T: 122,	G: 10,	avg_r: 1,	avg_G: 12.6,	t: 10,	dt: 275.258ms,	v: 6.64,	Rn: 5.48,	loss: 0.759,	training_step: 450
# [TrainMonitor|INFO] ep: 10,	T: 135,	G: 12,	avg_r: 1,	avg_G: 12.5,	t: 12,	dt: 42.542ms,	v: 7.66,	Rn: 6.48,	loss: 0.712,	training_step: 500
# [TrainMonitor|INFO] ep: 11,	T: 148,	G: 12,	avg_r: 1,	avg_G: 12.4,	t: 12,	dt: 43.956ms,	v: 7.63,	Rn: 6.48,	loss: 0.729,	training_step: 550,	test_G: 9.8
# [TrainMonitor|INFO] ep: 12,	T: 158,	G: 9,	avg_r: 1,	avg_G: 12.1,	t: 9,	dt: 279.631ms,	v: 12.6,	Rn: 4.99,	loss: 0.732,	training_step: 600
# [TrainMonitor|INFO] ep: 13,	T: 173,	G: 14,	avg_r: 1,	avg_G: 12.3,	t: 14,	dt: 188.471ms,	v: 7.79,	Rn: 7.47,	loss: 0.686,	training_step: 650
# [TrainMonitor|INFO] ep: 14,	T: 190,	G: 16,	avg_r: 1,	avg_G: 12.7,	t: 16,	dt: 172.538ms,	v: 12.7,	Rn: 8.46,	loss: 0.764,	training_step: 700
# [TrainMonitor|INFO] ep: 15,	T: 201,	G: 10,	avg_r: 1,	avg_G: 12.4,	t: 10,	dt: 248.276ms,	v: 12.5,	Rn: 5.48,	loss: 0.742,	training_step: 750
# [TrainMonitor|INFO] ep: 16,	T: 215,	G: 13,	avg_r: 1,	avg_G: 12.5,	t: 13,	dt: 39.196ms,	v: 7.29,	Rn: 6.97,	loss: 0.716,	training_step: 800
# [TrainMonitor|INFO] ep: 17,	T: 234,	G: 18,	avg_r: 1,	avg_G: 13,	t: 18,	dt: 28.586ms,	v: 8.8,	Rn: 9.45,	loss: 0.74,	training_step: 850
# [TrainMonitor|INFO] ep: 18,	T: 249,	G: 14,	avg_r: 1,	avg_G: 13.1,	t: 14,	dt: 34.578ms,	v: 13,	Rn: 7.47,	loss: 0.712,	training_step: 900
# [TrainMonitor|INFO] ep: 19,	T: 262,	G: 12,	avg_r: 1,	avg_G: 13,	t: 12,	dt: 41.954ms,	v: 7.36,	Rn: 6.48,	loss: 0.778,	training_step: 950
# [TrainMonitor|INFO] ep: 20,	T: 277,	G: 14,	avg_r: 1,	avg_G: 13.1,	t: 14,	dt: 35.622ms,	v: 7.53,	Rn: 7.47,	loss: 0.716,	training_step: 1e+03
# [TrainMonitor|INFO] ep: 21,	T: 288,	G: 10,	avg_r: 1,	avg_G: 12.8,	t: 10,	dt: 52.540ms,	v: 6.64,	Rn: 5.48,	loss: 0.732,	training_step: 1.05e+03,	test_G: 10.3
# [TrainMonitor|INFO] ep: 22,	T: 301,	G: 12,	avg_r: 1,	avg_G: 12.7,	t: 12,	dt: 40.719ms,	v: 12.6,	Rn: 6.48,	loss: 0.88,	training_step: 1.1e+03
# [TrainMonitor|INFO] ep: 23,	T: 312,	G: 10,	avg_r: 1,	avg_G: 12.4,	t: 10,	dt: 48.553ms,	v: 12.9,	Rn: 5.48,	loss: 0.784,	training_step: 1.15e+03
# [TrainMonitor|INFO] ep: 24,	T: 323,	G: 10,	avg_r: 1,	avg_G: 12.2,	t: 10,	dt: 51.523ms,	v: 6.45,	Rn: 5.48,	loss: 0.732,	training_step: 1.2e+03
# [TrainMonitor|INFO] ep: 25,	T: 338,	G: 14,	avg_r: 1,	avg_G: 12.4,	t: 14,	dt: 226.901ms,	v: 8.05,	Rn: 7.47,	loss: 0.713,	training_step: 1.25e+03
# [TrainMonitor|INFO] ep: 26,	T: 353,	G: 14,	avg_r: 1,	avg_G: 12.5,	t: 14,	dt: 35.083ms,	v: 8.19,	Rn: 7.47,	loss: 0.735,	training_step: 1.3e+03
# [TrainMonitor|INFO] ep: 27,	T: 383,	G: 29,	avg_r: 1,	avg_G: 14.2,	t: 29,	dt: 85.969ms,	v: 9.84,	Rn: 14.9,	loss: 0.777,	training_step: 1.35e+03
# [TrainMonitor|INFO] ep: 28,	T: 396,	G: 12,	avg_r: 1,	avg_G: 14,	t: 12,	dt: 40.615ms,	v: 7.31,	Rn: 6.48,	loss: 0.746,	training_step: 1.4e+03
# [TrainMonitor|INFO] ep: 29,	T: 411,	G: 14,	avg_r: 1,	avg_G: 14,	t: 14,	dt: 36.089ms,	v: 8.07,	Rn: 7.47,	loss: 0.763,	training_step: 1.45e+03
# [TrainMonitor|INFO] ep: 30,	T: 424,	G: 12,	avg_r: 1,	avg_G: 13.8,	t: 12,	dt: 42.242ms,	v: 7.62,	Rn: 6.48,	loss: 0.751,	training_step: 1.5e+03
# [TrainMonitor|INFO] ep: 31,	T: 439,	G: 14,	avg_r: 1,	avg_G: 13.8,	t: 14,	dt: 41.537ms,	v: 8.14,	Rn: 7.47,	loss: 0.738,	training_step: 1.55e+03,	test_G: 19.7
# [TrainMonitor|INFO] ep: 32,	T: 464,	G: 24,	avg_r: 1,	avg_G: 14.8,	t: 24,	dt: 20.779ms,	v: 8.88,	Rn: 12.4,	loss: 0.735,	training_step: 1.6e+03
# [TrainMonitor|INFO] ep: 33,	T: 485,	G: 20,	avg_r: 1,	avg_G: 15.3,	t: 20,	dt: 24.847ms,	v: 9.08,	Rn: 10.4,	loss: 0.75,	training_step: 1.65e+03
# [TrainMonitor|INFO] ep: 34,	T: 532,	G: 46,	avg_r: 1,	avg_G: 18.4,	t: 46,	dt: 11.319ms,	v: 10.5,	Rn: 23.2,	loss: 0.914,	training_step: 1.7e+03
# [TrainMonitor|INFO] ep: 35,	T: 568,	G: 35,	avg_r: 1,	avg_G: 20.1,	t: 35,	dt: 14.525ms,	v: 10.7,	Rn: 17.8,	loss: 0.838,	training_step: 1.75e+03
# [TrainMonitor|INFO] ep: 36,	T: 613,	G: 44,	avg_r: 1,	avg_G: 22.5,	t: 44,	dt: 11.997ms,	v: 12.3,	Rn: 22.2,	loss: 0.931,	training_step: 1.8e+03
# [TrainMonitor|INFO] ep: 37,	T: 649,	G: 35,	avg_r: 1,	avg_G: 23.7,	t: 35,	dt: 73.219ms,	v: 11.9,	Rn: 17.8,	loss: 0.978,	training_step: 1.85e+03
# [TrainMonitor|INFO] ep: 38,	T: 688,	G: 38,	avg_r: 1,	avg_G: 25.1,	t: 38,	dt: 21.166ms,	v: 13.1,	Rn: 19.3,	loss: 0.899,	training_step: 1.9e+03
# [TrainMonitor|INFO] ep: 39,	T: 703,	G: 14,	avg_r: 1,	avg_G: 24,	t: 14,	dt: 181.465ms,	v: 9.21,	Rn: 7.47,	loss: 0.933,	training_step: 1.95e+03
# [TrainMonitor|INFO] ep: 40,	T: 716,	G: 12,	avg_r: 1,	avg_G: 22.8,	t: 12,	dt: 383.898ms,	v: 7.66,	Rn: 6.48,	loss: 0.895,	training_step: 2e+03
# [TrainMonitor|INFO] ep: 41,	T: 733,	G: 16,	avg_r: 1,	avg_G: 22.1,	t: 16,	dt: 36.096ms,	v: 8.31,	Rn: 8.46,	loss: 0.884,	training_step: 2.05e+03,	test_G: 16.2
# [TrainMonitor|INFO] ep: 42,	T: 748,	G: 14,	avg_r: 1,	avg_G: 21.3,	t: 14,	dt: 187.131ms,	v: 8.03,	Rn: 7.47,	loss: 0.866,	training_step: 2.1e+03
# [TrainMonitor|INFO] ep: 43,	T: 774,	G: 25,	avg_r: 1,	avg_G: 21.7,	t: 25,	dt: 20.518ms,	v: 13.4,	Rn: 12.9,	loss: 0.871,	training_step: 2.15e+03
# [TrainMonitor|INFO] ep: 44,	T: 786,	G: 11,	avg_r: 1,	avg_G: 20.6,	t: 11,	dt: 74.901ms,	v: 6.79,	Rn: 5.98,	loss: 0.927,	training_step: 2.2e+03
# [TrainMonitor|INFO] ep: 45,	T: 818,	G: 31,	avg_r: 1,	avg_G: 21.7,	t: 31,	dt: 82.768ms,	v: 12.8,	Rn: 15.8,	loss: 0.891,	training_step: 2.25e+03
# [TrainMonitor|INFO] ep: 46,	T: 856,	G: 37,	avg_r: 1,	avg_G: 23.2,	t: 37,	dt: 14.476ms,	v: 15,	Rn: 18.8,	loss: 0.935,	training_step: 2.3e+03
# [TrainMonitor|INFO] ep: 47,	T: 893,	G: 36,	avg_r: 1,	avg_G: 24.5,	t: 36,	dt: 14.933ms,	v: 14.7,	Rn: 18.3,	loss: 0.926,	training_step: 2.35e+03
# [TrainMonitor|INFO] ep: 48,	T: 904,	G: 10,	avg_r: 1,	avg_G: 23,	t: 10,	dt: 51.618ms,	v: 6.7,	Rn: 5.48,	loss: 0.924,	training_step: 2.4e+03
# [TrainMonitor|INFO] ep: 49,	T: 915,	G: 10,	avg_r: 1,	avg_G: 21.7,	t: 10,	dt: 52.469ms,	v: 20.7,	Rn: 5.48,	loss: 0.904,	training_step: 2.45e+03
# [TrainMonitor|INFO] ep: 50,	T: 955,	G: 39,	avg_r: 1,	avg_G: 23.5,	t: 39,	dt: 13.544ms,	v: 14.8,	Rn: 19.7,	loss: 0.952,	training_step: 2.5e+03
# [TrainMonitor|INFO] ep: 51,	T: 967,	G: 11,	avg_r: 1,	avg_G: 22.2,	t: 11,	dt: 57.552ms,	v: 19.8,	Rn: 5.98,	loss: 0.962,	training_step: 2.55e+03,	test_G: 27.5
# [TrainMonitor|INFO] ep: 52,	T: 1,009,	G: 41,	avg_r: 1,	avg_G: 24.1,	t: 41,	dt: 14.661ms,	v: 13.1,	Rn: 20.7,	loss: 1.08,	training_step: 2.6e+03
# [TrainMonitor|INFO] ep: 53,	T: 1,050,	G: 40,	avg_r: 1,	avg_G: 25.7,	t: 40,	dt: 13.244ms,	v: 14.6,	Rn: 20.2,	loss: 1.01,	training_step: 2.65e+03
# [TrainMonitor|INFO] ep: 54,	T: 1,086,	G: 35,	avg_r: 1,	avg_G: 26.6,	t: 35,	dt: 15.041ms,	v: 15.3,	Rn: 17.8,	loss: 1.04,	training_step: 2.7e+03
# [TrainMonitor|INFO] ep: 55,	T: 1,125,	G: 38,	avg_r: 1,	avg_G: 27.7,	t: 38,	dt: 15.231ms,	v: 16,	Rn: 19.3,	loss: 0.989,	training_step: 2.75e+03
# [TrainMonitor|INFO] ep: 56,	T: 1,138,	G: 12,	avg_r: 1,	avg_G: 26.2,	t: 12,	dt: 219.707ms,	v: 7.33,	Rn: 6.48,	loss: 0.982,	training_step: 2.8e+03
# [TrainMonitor|INFO] ep: 57,	T: 1,171,	G: 32,	avg_r: 1,	avg_G: 26.8,	t: 32,	dt: 16.823ms,	v: 15.1,	Rn: 16.3,	loss: 0.981,	training_step: 2.85e+03
# [TrainMonitor|INFO] ep: 58,	T: 1,212,	G: 40,	avg_r: 1,	avg_G: 28.1,	t: 40,	dt: 13.598ms,	v: 14.6,	Rn: 20.2,	loss: 1.02,	training_step: 2.9e+03
# [TrainMonitor|INFO] ep: 59,	T: 1,248,	G: 35,	avg_r: 1,	avg_G: 28.8,	t: 35,	dt: 24.264ms,	v: 16,	Rn: 17.8,	loss: 1.01,	training_step: 2.95e+03
# [TrainMonitor|INFO] ep: 60,	T: 1,277,	G: 28,	avg_r: 1,	avg_G: 28.7,	t: 28,	dt: 19.210ms,	v: 16,	Rn: 14.4,	loss: 1.03,	training_step: 3e+03
# [TrainMonitor|INFO] ep: 61,	T: 1,314,	G: 36,	avg_r: 1,	avg_G: 29.4,	t: 36,	dt: 20.334ms,	v: 15.2,	Rn: 18.3,	loss: 1.03,	training_step: 3.05e+03,	test_G: 34.5
# [TrainMonitor|INFO] ep: 62,	T: 1,349,	G: 34,	avg_r: 1,	avg_G: 29.9,	t: 34,	dt: 16.532ms,	v: 15.9,	Rn: 17.3,	loss: 1.02,	training_step: 3.1e+03
# [TrainMonitor|INFO] ep: 63,	T: 1,385,	G: 35,	avg_r: 1,	avg_G: 30.4,	t: 35,	dt: 15.464ms,	v: 13.4,	Rn: 17.8,	loss: 1.03,	training_step: 3.15e+03
# [TrainMonitor|INFO] ep: 64,	T: 1,418,	G: 32,	avg_r: 1,	avg_G: 30.6,	t: 32,	dt: 16.588ms,	v: 16.6,	Rn: 16.3,	loss: 1.05,	training_step: 3.2e+03
# [TrainMonitor|INFO] ep: 65,	T: 1,453,	G: 34,	avg_r: 1,	avg_G: 30.9,	t: 34,	dt: 75.388ms,	v: 16.1,	Rn: 17.3,	loss: 1.03,	training_step: 3.25e+03
# [TrainMonitor|INFO] ep: 66,	T: 1,490,	G: 36,	avg_r: 1,	avg_G: 31.4,	t: 36,	dt: 70.800ms,	v: 16.2,	Rn: 18.3,	loss: 1.09,	training_step: 3.3e+03
# [TrainMonitor|INFO] ep: 67,	T: 1,516,	G: 25,	avg_r: 1,	avg_G: 30.8,	t: 25,	dt: 106.566ms,	v: 16.5,	Rn: 12.9,	loss: 1.08,	training_step: 3.35e+03
# [TrainMonitor|INFO] ep: 68,	T: 1,556,	G: 39,	avg_r: 1,	avg_G: 31.6,	t: 39,	dt: 14.088ms,	v: 15.1,	Rn: 19.7,	loss: 1.06,	training_step: 3.4e+03
# [TrainMonitor|INFO] ep: 69,	T: 1,590,	G: 33,	avg_r: 1,	avg_G: 31.7,	t: 33,	dt: 18.122ms,	v: 21.4,	Rn: 16.8,	loss: 1.05,	training_step: 3.45e+03
# [TrainMonitor|INFO] ep: 70,	T: 1,624,	G: 33,	avg_r: 1,	avg_G: 31.9,	t: 33,	dt: 17.643ms,	v: 15.7,	Rn: 16.8,	loss: 1.04,	training_step: 3.5e+03
# [TrainMonitor|INFO] ep: 71,	T: 1,664,	G: 39,	avg_r: 1,	avg_G: 32.6,	t: 39,	dt: 28.314ms,	v: 15.4,	Rn: 19.7,	loss: 1.08,	training_step: 3.55e+03,	test_G: 41.8
# [TrainMonitor|INFO] ep: 72,	T: 1,710,	G: 45,	avg_r: 1,	avg_G: 33.8,	t: 45,	dt: 12.089ms,	v: 14.8,	Rn: 22.7,	loss: 1.07,	training_step: 3.6e+03
# [TrainMonitor|INFO] ep: 73,	T: 1,739,	G: 28,	avg_r: 1,	avg_G: 33.2,	t: 28,	dt: 20.274ms,	v: 14.7,	Rn: 14.4,	loss: 1.07,	training_step: 3.65e+03
# [TrainMonitor|INFO] ep: 74,	T: 1,777,	G: 37,	avg_r: 1,	avg_G: 33.6,	t: 37,	dt: 69.613ms,	v: 15.6,	Rn: 18.8,	loss: 1.09,	training_step: 3.7e+03
# [TrainMonitor|INFO] ep: 75,	T: 1,821,	G: 43,	avg_r: 1,	avg_G: 34.6,	t: 43,	dt: 12.518ms,	v: 15.4,	Rn: 21.7,	loss: 1.08,	training_step: 3.75e+03
# [TrainMonitor|INFO] ep: 76,	T: 1,869,	G: 47,	avg_r: 1,	avg_G: 35.8,	t: 47,	dt: 11.597ms,	v: 15.7,	Rn: 23.6,	loss: 1.15,	training_step: 3.8e+03
# [TrainMonitor|INFO] ep: 77,	T: 1,914,	G: 44,	avg_r: 1,	avg_G: 36.6,	t: 44,	dt: 12.436ms,	v: 16,	Rn: 22.2,	loss: 1.11,	training_step: 3.85e+03
# [TrainMonitor|INFO] ep: 78,	T: 1,955,	G: 40,	avg_r: 1,	avg_G: 37,	t: 40,	dt: 13.590ms,	v: 16.3,	Rn: 20.2,	loss: 1.09,	training_step: 3.9e+03
# [TrainMonitor|INFO] ep: 79,	T: 2,001,	G: 45,	avg_r: 1,	avg_G: 37.8,	t: 45,	dt: 12.062ms,	v: 15.7,	Rn: 22.7,	loss: 1.13,	training_step: 3.95e+03
# [TrainMonitor|INFO] ep: 93,	T: 2,406,	G: 22,	avg_r: 1,	avg_G: 28.6,	t: 22,	dt: 24.683ms,	v: 20.8,	Rn: 11.4,	loss: 1.23,	training_step: 4.65e+03
# [TrainMonitor|INFO] ep: 94,	T: 2,440,	G: 33,	avg_r: 1,	avg_G: 29,	t: 33,	dt: 16.591ms,	v: 18.7,	Rn: 16.8,	loss: 1.22,	training_step: 4.7e+03
# [TrainMonitor|INFO] ep: 95,	T: 2,461,	G: 20,	avg_r: 1,	avg_G: 28.1,	t: 20,	dt: 145.313ms,	v: 20.1,	Rn: 10.4,	loss: 1.21,	training_step: 4.75e+03
# [TrainMonitor|INFO] ep: 96,	T: 2,496,	G: 34,	avg_r: 1,	avg_G: 28.7,	t: 34,	dt: 16.166ms,	v: 18.4,	Rn: 17.3,	loss: 1.23,	training_step: 4.8e+03
# [TrainMonitor|INFO] ep: 97,	T: 2,530,	G: 33,	avg_r: 1,	avg_G: 29.1,	t: 33,	dt: 16.674ms,	v: 20.9,	Rn: 16.8,	loss: 1.25,	training_step: 4.85e+03
# [TrainMonitor|INFO] ep: 98,	T: 2,549,	G: 18,	avg_r: 1,	avg_G: 28,	t: 18,	dt: 30.387ms,	v: 20.8,	Rn: 9.45,	loss: 1.29,	training_step: 4.9e+03
# [TrainMonitor|INFO] ep: 99,	T: 2,582,	G: 32,	avg_r: 1,	avg_G: 28.4,	t: 32,	dt: 17.315ms,	v: 20.2,	Rn: 16.3,	loss: 1.25,	training_step: 4.95e+03
# [TrainMonitor|INFO] ep: 100,	T: 2,628,	G: 45,	avg_r: 1,	avg_G: 30.1,	t: 45,	dt: 12.507ms,	v: 14.8,	Rn: 22.7,	loss: 1.27,	training_step: 5e+03
# [TrainMonitor|INFO] ep: 101,	T: 2,662,	G: 33,	avg_r: 1,	avg_G: 30.4,	t: 33,	dt: 19.297ms,	v: 19.6,	Rn: 16.8,	loss: 1.24,	training_step: 5.05e+03,	test_G: 21
# [TrainMonitor|INFO] ep: 102,	T: 2,674,	G: 11,	avg_r: 1,	avg_G: 28.4,	t: 11,	dt: 232.976ms,	v: 21.1,	Rn: 5.98,	loss: 1.25,	training_step: 5.1e+03
# [TrainMonitor|INFO] ep: 103,	T: 2,687,	G: 12,	avg_r: 1,	avg_G: 26.8,	t: 12,	dt: 45.838ms,	v: 21.7,	Rn: 6.48,	loss: 1.29,	training_step: 5.15e+03
# [TrainMonitor|INFO] ep: 104,	T: 2,713,	G: 25,	avg_r: 1,	avg_G: 26.6,	t: 25,	dt: 22.179ms,	v: 20.1,	Rn: 12.9,	loss: 1.28,	training_step: 5.2e+03
# [TrainMonitor|INFO] ep: 105,	T: 2,739,	G: 25,	avg_r: 1,	avg_G: 26.4,	t: 25,	dt: 22.207ms,	v: 19.4,	Rn: 12.9,	loss: 1.29,	training_step: 5.25e+03
# [TrainMonitor|INFO] ep: 106,	T: 2,749,	G: 9,	avg_r: 1,	avg_G: 24.7,	t: 9,	dt: 61.571ms,	v: 21.7,	Rn: 4.99,	loss: 1.31,	training_step: 5.3e+03
# [TrainMonitor|INFO] ep: 107,	T: 2,773,	G: 23,	avg_r: 1,	avg_G: 24.5,	t: 23,	dt: 24.340ms,	v: 19.9,	Rn: 11.9,	loss: 1.31,	training_step: 5.35e+03
# [TrainMonitor|INFO] ep: 108,	T: 2,814,	G: 40,	avg_r: 1,	avg_G: 26.1,	t: 40,	dt: 14.125ms,	v: 14.7,	Rn: 20.2,	loss: 1.27,	training_step: 5.4e+03
# [TrainMonitor|INFO] ep: 109,	T: 2,851,	G: 36,	avg_r: 1,	avg_G: 27.1,	t: 36,	dt: 70.786ms,	v: 15.3,	Rn: 18.3,	loss: 1.33,	training_step: 5.45e+03
# [TrainMonitor|INFO] ep: 110,	T: 2,890,	G: 38,	avg_r: 1,	avg_G: 28.2,	t: 38,	dt: 14.867ms,	v: 15.7,	Rn: 19.3,	loss: 1.3,	training_step: 5.5e+03
# [TrainMonitor|INFO] ep: 111,	T: 2,922,	G: 31,	avg_r: 1,	avg_G: 28.4,	t: 31,	dt: 103.772ms,	v: 17.9,	Rn: 15.8,	loss: 1.3,	training_step: 5.55e+03,	test_G: 33.8
# [TrainMonitor|INFO] ep: 112,	T: 2,948,	G: 25,	avg_r: 1,	avg_G: 28.1,	t: 25,	dt: 24.314ms,	v: 19.3,	Rn: 12.9,	loss: 1.28,	training_step: 5.6e+03
# [TrainMonitor|INFO] ep: 113,	T: 2,985,	G: 36,	avg_r: 1,	avg_G: 28.9,	t: 36,	dt: 16.707ms,	v: 15.1,	Rn: 18.3,	loss: 1.31,	training_step: 5.65e+03
# [TrainMonitor|INFO] ep: 114,	T: 3,053,	G: 67,	avg_r: 1,	avg_G: 32.7,	t: 67,	dt: 9.006ms,	v: 13,	Rn: 32.9,	loss: 1.37,	training_step: 5.7e+03
# [TrainMonitor|INFO] ep: 115,	T: 3,080,	G: 26,	avg_r: 1,	avg_G: 32,	t: 26,	dt: 22.293ms,	v: 20,	Rn: 13.4,	loss: 1.37,	training_step: 5.75e+03
# [TrainMonitor|INFO] ep: 116,	T: 3,128,	G: 47,	avg_r: 1,	avg_G: 33.5,	t: 47,	dt: 12.684ms,	v: 14.5,	Rn: 23.6,	loss: 1.37,	training_step: 5.8e+03
# [TrainMonitor|INFO] ep: 117,	T: 3,153,	G: 24,	avg_r: 1,	avg_G: 32.6,	t: 24,	dt: 24.841ms,	v: 20.2,	Rn: 12.4,	loss: 1.35,	training_step: 5.85e+03
# [TrainMonitor|INFO] ep: 118,	T: 3,179,	G: 25,	avg_r: 1,	avg_G: 31.8,	t: 25,	dt: 105.342ms,	v: 20.5,	Rn: 12.9,	loss: 1.35,	training_step: 5.9e+03
# [TrainMonitor|INFO] ep: 119,	T: 3,202,	G: 22,	avg_r: 1,	avg_G: 30.8,	t: 22,	dt: 25.812ms,	v: 20.3,	Rn: 11.4,	loss: 1.35,	training_step: 5.95e+03
# [TrainMonitor|INFO] ep: 120,	T: 3,242,	G: 39,	avg_r: 1,	avg_G: 31.7,	t: 39,	dt: 15.086ms,	v: 15.1,	Rn: 19.7,	loss: 1.37,	training_step: 6e+03
# [TrainMonitor|INFO] ep: 202,	T: 7,517,	G: 81,	avg_r: 1,	avg_G: 60.6,	t: 81,	dt: 8.009ms,	v: 35.4,	Rn: 48.1,	loss: 1.86,	training_step: 1.01e+04
# [TrainMonitor|INFO] ep: 203,	T: 7,554,	G: 36,	avg_r: 1,	avg_G: 58.2,	t: 36,	dt: 18.556ms,	v: 32.1,	Rn: 18.3,	loss: 1.85,	training_step: 1.02e+04
# [TrainMonitor|INFO] ep: 204,	T: 7,644,	G: 89,	avg_r: 1,	avg_G: 61.2,	t: 89,	dt: 7.359ms,	v: 33.3,	Rn: 49.8,	loss: 1.86,	training_step: 1.02e+04
# [TrainMonitor|INFO] ep: 205,	T: 7,703,	G: 58,	avg_r: 1,	avg_G: 60.9,	t: 58,	dt: 11.739ms,	v: 34.1,	Rn: 33.3,	loss: 1.87,	training_step: 1.02e+04
# [TrainMonitor|INFO] ep: 206,	T: 7,793,	G: 89,	avg_r: 1,	avg_G: 63.7,	t: 89,	dt: 7.728ms,	v: 32.2,	Rn: 49,	loss: 1.87,	training_step: 1.03e+04
# [TrainMonitor|INFO] ep: 207,	T: 7,849,	G: 55,	avg_r: 1,	avg_G: 62.9,	t: 55,	dt: 12.045ms,	v: 35.5,	Rn: 30.6,	loss: 1.9,	training_step: 1.04e+04
# [TrainMonitor|INFO] ep: 208,	T: 7,934,	G: 84,	avg_r: 1,	avg_G: 65,	t: 84,	dt: 7.891ms,	v: 36.6,	Rn: 48.6,	loss: 1.88,	training_step: 1.04e+04
# [TrainMonitor|INFO] ep: 209,	T: 8,033,	G: 98,	avg_r: 1,	avg_G: 68.3,	t: 98,	dt: 6.717ms,	v: 31.2,	Rn: 50.4,	loss: 1.88,	training_step: 1.04e+04
# [TrainMonitor|INFO] ep: 210,	T: 8,124,	G: 90,	avg_r: 1,	avg_G: 70.4,	t: 90,	dt: 12.818ms,	v: 35.4,	Rn: 51,	loss: 1.88,	training_step: 1.05e+04
# [TrainMonitor|INFO] ep: 211,	T: 8,173,	G: 48,	avg_r: 1,	avg_G: 68.2,	t: 48,	dt: 21.112ms,	v: 38.5,	Rn: 24.1,	loss: 1.89,	training_step: 1.06e+04,	test_G: 95.6
# [TrainMonitor|INFO] ep: 212,	T: 8,277,	G: 103,	avg_r: 1,	avg_G: 71.7,	t: 103,	dt: 6.380ms,	v: 33.1,	Rn: 52.8,	loss: 1.9,	training_step: 1.06e+04
# [TrainMonitor|INFO] ep: 213,	T: 8,359,	G: 81,	avg_r: 1,	avg_G: 72.6,	t: 81,	dt: 7.982ms,	v: 36.1,	Rn: 47.2,	loss: 1.9,	training_step: 1.06e+04
# [TrainMonitor|INFO] ep: 214,	T: 8,462,	G: 102,	avg_r: 1,	avg_G: 75.6,	t: 102,	dt: 6.471ms,	v: 32.7,	Rn: 52.2,	loss: 1.9,	training_step: 1.07e+04
# [TrainMonitor|INFO] ep: 215,	T: 8,572,	G: 109,	avg_r: 1,	avg_G: 78.9,	t: 109,	dt: 6.455ms,	v: 30.7,	Rn: 51.8,	loss: 1.92,	training_step: 1.08e+04
# [TrainMonitor|INFO] ep: 230,	T: 9,649,	G: 45,	avg_r: 1,	avg_G: 70.3,	t: 45,	dt: 14.209ms,	v: 40,	Rn: 22.7,	loss: 1.94,	training_step: 1.15e+04
# [TrainMonitor|INFO] ep: 231,	T: 9,748,	G: 98,	avg_r: 1,	avg_G: 73.1,	t: 98,	dt: 10.392ms,	v: 33.9,	Rn: 49.2,	loss: 1.95,	training_step: 1.16e+04,	test_G: 101
# [TrainMonitor|INFO] ep: 232,	T: 9,809,	G: 60,	avg_r: 1,	avg_G: 71.8,	t: 60,	dt: 10.783ms,	v: 40.1,	Rn: 35.5,	loss: 1.92,	training_step: 1.16e+04
# [TrainMonitor|INFO] ep: 233,	T: 9,822,	G: 12,	avg_r: 1,	avg_G: 65.8,	t: 12,	dt: 52.335ms,	v: 34.5,	Rn: 6.48,	loss: 1.97,	training_step: 1.16e+04
# [TrainMonitor|INFO] ep: 234,	T: 9,907,	G: 84,	avg_r: 1,	avg_G: 67.6,	t: 84,	dt: 7.825ms,	v: 35.3,	Rn: 46.1,	loss: 1.94,	training_step: 1.17e+04
# [TrainMonitor|INFO] ep: 235,	T: 9,983,	G: 75,	avg_r: 1,	avg_G: 68.4,	t: 75,	dt: 42.030ms,	v: 36.8,	Rn: 44.1,	loss: 1.92,	training_step: 1.18e+04
# [TrainMonitor|INFO] ep: 236,	T: 10,048,	G: 64,	avg_r: 1,	avg_G: 67.9,	t: 64,	dt: 10.221ms,	v: 40.9,	Rn: 38.8,	loss: 1.93,	training_step: 1.18e+04
# [TrainMonitor|INFO] ep: 237,	T: 10,059,	G: 10,	avg_r: 1,	avg_G: 62.1,	t: 10,	dt: 63.415ms,	v: 35.8,	Rn: 5.48,	loss: 1.95,	training_step: 1.18e+04
# [TrainMonitor|INFO] ep: 238,	T: 10,118,	G: 58,	avg_r: 1,	avg_G: 61.7,	t: 58,	dt: 11.233ms,	v: 38.6,	Rn: 31.9,	loss: 1.95,	training_step: 1.19e+04
# [TrainMonitor|INFO] ep: 239,	T: 10,200,	G: 81,	avg_r: 1,	avg_G: 63.6,	t: 81,	dt: 8.239ms,	v: 40.6,	Rn: 48.2,	loss: 1.93,	training_step: 1.2e+04
# [TrainMonitor|INFO] ep: 240,	T: 10,219,	G: 18,	avg_r: 1,	avg_G: 59.1,	t: 18,	dt: 35.151ms,	v: 38,	Rn: 9.45,	loss: 1.94,	training_step: 1.2e+04
# [TrainMonitor|INFO] ep: 241,	T: 10,327,	G: 107,	avg_r: 1,	avg_G: 63.9,	t: 107,	dt: 8.951ms,	v: 34.5,	Rn: 52.1,	loss: 1.94,	training_step: 1.2e+04,	test_G: 79.2
# [TrainMonitor|INFO] ep: 242,	T: 10,403,	G: 75,	avg_r: 1,	avg_G: 65,	t: 75,	dt: 8.859ms,	v: 37.4,	Rn: 43.9,	loss: 1.93,	training_step: 1.21e+04
# [TrainMonitor|INFO] ep: 257,	T: 11,492,	G: 77,	avg_r: 1,	avg_G: 69.4,	t: 77,	dt: 34.464ms,	v: 37.4,	Rn: 44,	loss: 1.96,	training_step: 1.28e+04
# [TrainMonitor|INFO] ep: 258,	T: 11,581,	G: 88,	avg_r: 1,	avg_G: 71.3,	t: 88,	dt: 7.614ms,	v: 38.9,	Rn: 48.9,	loss: 1.97,	training_step: 1.29e+04
# [TrainMonitor|INFO] ep: 259,	T: 11,600,	G: 18,	avg_r: 1,	avg_G: 65.9,	t: 18,	dt: 36.276ms,	v: 40.7,	Rn: 9.45,	loss: 1.98,	training_step: 1.3e+04
# [TrainMonitor|INFO] ep: 260,	T: 11,676,	G: 75,	avg_r: 1,	avg_G: 66.9,	t: 75,	dt: 16.169ms,	v: 40.1,	Rn: 43.7,	loss: 1.97,	training_step: 1.3e+04
# [TrainMonitor|INFO] ep: 261,	T: 11,765,	G: 88,	avg_r: 1,	avg_G: 69,	t: 88,	dt: 11.011ms,	v: 36.3,	Rn: 48.1,	loss: 1.95,	training_step: 1.3e+04,	test_G: 82.5
# [TrainMonitor|INFO] ep: 262,	T: 11,852,	G: 86,	avg_r: 1,	avg_G: 70.7,	t: 86,	dt: 7.823ms,	v: 36.6,	Rn: 46.7,	loss: 1.98,	training_step: 1.31e+04
# [TrainMonitor|INFO] ep: 263,	T: 11,961,	G: 108,	avg_r: 1,	avg_G: 74.4,	t: 108,	dt: 6.324ms,	v: 34.9,	Rn: 52.2,	loss: 1.97,	training_step: 1.32e+04
# [TrainMonitor|INFO] ep: 264,	T: 12,042,	G: 80,	avg_r: 1,	avg_G: 75,	t: 80,	dt: 8.491ms,	v: 36.1,	Rn: 44.3,	loss: 1.98,	training_step: 1.32e+04
# [TrainMonitor|INFO] ep: 265,	T: 12,117,	G: 74,	avg_r: 1,	avg_G: 74.9,	t: 74,	dt: 9.067ms,	v: 34.3,	Rn: 39.9,	loss: 1.96,	training_step: 1.32e+04
# [TrainMonitor|INFO] ep: 266,	T: 12,194,	G: 76,	avg_r: 1,	avg_G: 75,	t: 76,	dt: 8.774ms,	v: 38.4,	Rn: 42.6,	loss: 1.96,	training_step: 1.33e+04
# [TrainMonitor|INFO] ep: 267,	T: 12,260,	G: 65,	avg_r: 1,	avg_G: 74,	t: 65,	dt: 10.266ms,	v: 38.4,	Rn: 36,	loss: 1.96,	training_step: 1.34e+04
# [TrainMonitor|INFO] ep: 268,	T: 12,333,	G: 72,	avg_r: 1,	avg_G: 73.8,	t: 72,	dt: 9.296ms,	v: 35.5,	Rn: 39.6,	loss: 1.97,	training_step: 1.34e+04
# [TrainMonitor|INFO] ep: 269,	T: 12,435,	G: 101,	avg_r: 1,	avg_G: 76.5,	t: 101,	dt: 6.745ms,	v: 34.2,	Rn: 50.3,	loss: 1.96,	training_step: 1.34e+04
# [TrainMonitor|INFO] ep: 270,	T: 12,518,	G: 82,	avg_r: 1,	avg_G: 77.1,	t: 82,	dt: 8.205ms,	v: 35.1,	Rn: 43.8,	loss: 1.98,	training_step: 1.35e+04
# [TrainMonitor|INFO] ep: 312,	T: 15,672,	G: 84,	avg_r: 1,	avg_G: 83.7,	t: 84,	dt: 8.141ms,	v: 41.3,	Rn: 46.7,	loss: 1.99,	training_step: 1.56e+04
# [TrainMonitor|INFO] ep: 313,	T: 15,788,	G: 115,	avg_r: 1,	avg_G: 86.8,	t: 115,	dt: 6.080ms,	v: 33.3,	Rn: 51.9,	loss: 1.97,	training_step: 1.56e+04
# [TrainMonitor|INFO] ep: 314,	T: 15,889,	G: 100,	avg_r: 1,	avg_G: 88.2,	t: 100,	dt: 6.872ms,	v: 39.1,	Rn: 50.9,	loss: 1.98,	training_step: 1.57e+04
# [TrainMonitor|INFO] ep: 315,	T: 15,970,	G: 80,	avg_r: 1,	avg_G: 87.3,	t: 80,	dt: 8.680ms,	v: 36.2,	Rn: 42.5,	loss: 2,	training_step: 1.58e+04
# [TrainMonitor|INFO] ep: 316,	T: 16,068,	G: 97,	avg_r: 1,	avg_G: 88.3,	t: 97,	dt: 7.113ms,	v: 33.6,	Rn: 47.9,	loss: 1.98,	training_step: 1.58e+04
# [TrainMonitor|INFO] ep: 317,	T: 16,166,	G: 97,	avg_r: 1,	avg_G: 89.2,	t: 97,	dt: 7.084ms,	v: 36.2,	Rn: 48,	loss: 1.99,	training_step: 1.58e+04
# [TrainMonitor|INFO] ep: 318,	T: 16,254,	G: 87,	avg_r: 1,	avg_G: 89,	t: 87,	dt: 7.867ms,	v: 38.6,	Rn: 47.9,	loss: 1.99,	training_step: 1.59e+04
# [TrainMonitor|INFO] ep: 319,	T: 16,340,	G: 85,	avg_r: 1,	avg_G: 88.6,	t: 85,	dt: 8.050ms,	v: 36.3,	Rn: 44.1,	loss: 1.97,	training_step: 1.6e+04
# [TrainMonitor|INFO] ep: 320,	T: 16,450,	G: 109,	avg_r: 1,	avg_G: 90.6,	t: 109,	dt: 11.358ms,	v: 32.9,	Rn: 51,	loss: 1.99,	training_step: 1.6e+04
# [TrainMonitor|INFO] ep: 321,	T: 16,557,	G: 106,	avg_r: 1,	avg_G: 92.1,	t: 106,	dt: 8.825ms,	v: 34.6,	Rn: 51.3,	loss: 1.97,	training_step: 1.6e+04,	test_G: 67.6
# [TrainMonitor|INFO] ep: 322,	T: 16,637,	G: 79,	avg_r: 1,	avg_G: 90.8,	t: 79,	dt: 9.203ms,	v: 39.7,	Rn: 43.8,	loss: 1.97,	training_step: 1.61e+04
# [TrainMonitor|INFO] ep: 323,	T: 16,758,	G: 120,	avg_r: 1,	avg_G: 93.7,	t: 120,	dt: 5.847ms,	v: 32.3,	Rn: 52.2,	loss: 1.97,	training_step: 1.62e+04
# [TrainMonitor|INFO] ep: 324,	T: 16,871,	G: 112,	avg_r: 1,	avg_G: 95.6,	t: 112,	dt: 6.282ms,	v: 36,	Rn: 51.7,	loss: 1.99,	training_step: 1.62e+04
# [TrainMonitor|INFO] ep: 325,	T: 16,986,	G: 114,	avg_r: 1,	avg_G: 97.4,	t: 114,	dt: 6.177ms,	v: 34.9,	Rn: 51.8,	loss: 1.98,	training_step: 1.62e+04
# [TrainMonitor|INFO] ep: 326,	T: 17,003,	G: 16,	avg_r: 1,	avg_G: 89.3,	t: 16,	dt: 41.370ms,	v: 48,	Rn: 8.46,	loss: 2,	training_step: 1.63e+04
# [TrainMonitor|INFO] ep: 327,	T: 17,089,	G: 85,	avg_r: 1,	avg_G: 88.8,	t: 85,	dt: 8.101ms,	v: 35.1,	Rn: 44.3,	loss: 2,	training_step: 1.64e+04
# [TrainMonitor|INFO] ep: 328,	T: 17,160,	G: 70,	avg_r: 1,	avg_G: 87,	t: 70,	dt: 9.731ms,	v: 42.4,	Rn: 40.2,	loss: 1.97,	training_step: 1.64e+04
# [TrainMonitor|INFO] ep: 329,	T: 17,258,	G: 97,	avg_r: 1,	avg_G: 88,	t: 97,	dt: 7.101ms,	v: 36.8,	Rn: 49.1,	loss: 1.98,	training_step: 1.64e+04
# [TrainMonitor|INFO] ep: 330,	T: 17,359,	G: 100,	avg_r: 1,	avg_G: 89.2,	t: 100,	dt: 27.114ms,	v: 35.9,	Rn: 48.9,	loss: 1.97,	training_step: 1.65e+04
# [TrainMonitor|INFO] ep: 331,	T: 17,475,	G: 115,	avg_r: 1,	avg_G: 91.8,	t: 115,	dt: 8.176ms,	v: 35.6,	Rn: 52,	loss: 2,	training_step: 1.66e+04,	test_G: 60.8
# ...
# [TrainMonitor|INFO] ep: 561,	T: 42,258,	G: 130,	avg_r: 1,	avg_G: 107,	t: 130,	dt: 8.924ms,	v: 46.5,	Rn: 60.5,	loss: 2.01,	training_step: 2.8e+04,	test_G: 108
# [TrainMonitor|INFO] ep: 562,	T: 42,380,	G: 121,	avg_r: 1,	avg_G: 109,	t: 121,	dt: 6.287ms,	v: 48.9,	Rn: 60.9,	loss: 2.02,	training_step: 2.81e+04
# [TrainMonitor|INFO] ep: 563,	T: 42,504,	G: 123,	avg_r: 1,	avg_G: 110,	t: 123,	dt: 6.457ms,	v: 49.6,	Rn: 61.4,	loss: 2.02,	training_step: 2.82e+04
# [TrainMonitor|INFO] ep: 564,	T: 42,623,	G: 118,	avg_r: 1,	avg_G: 111,	t: 118,	dt: 6.621ms,	v: 49.4,	Rn: 60,	loss: 2.02,	training_step: 2.82e+04
# [TrainMonitor|INFO] ep: 565,	T: 42,636,	G: 12,	avg_r: 1,	avg_G: 101,	t: 12,	dt: 60.274ms,	v: 45.2,	Rn: 6.48,	loss: 2.02,	training_step: 2.82e+04
# [TrainMonitor|INFO] ep: 566,	T: 42,782,	G: 145,	avg_r: 1,	avg_G: 105,	t: 145,	dt: 5.360ms,	v: 42.9,	Rn: 61.6,	loss: 2.01,	training_step: 2.83e+04
# [TrainMonitor|INFO] ep: 567,	T: 42,905,	G: 122,	avg_r: 1,	avg_G: 107,	t: 122,	dt: 6.291ms,	v: 47.5,	Rn: 59.1,	loss: 2.01,	training_step: 2.84e+04
# [TrainMonitor|INFO] ep: 582,	T: 44,340,	G: 13,	avg_r: 1,	avg_G: 94.5,	t: 13,	dt: 56.284ms,	v: 46,	Rn: 6.97,	loss: 2,	training_step: 2.91e+04
# [TrainMonitor|INFO] ep: 583,	T: 44,456,	G: 115,	avg_r: 1,	avg_G: 96.5,	t: 115,	dt: 6.673ms,	v: 50.5,	Rn: 60,	loss: 2,	training_step: 2.92e+04
# [TrainMonitor|INFO] ep: 584,	T: 44,474,	G: 17,	avg_r: 1,	avg_G: 88.6,	t: 17,	dt: 43.148ms,	v: 42.3,	Rn: 8.95,	loss: 2,	training_step: 2.92e+04
# [TrainMonitor|INFO] ep: 585,	T: 44,599,	G: 124,	avg_r: 1,	avg_G: 92.1,	t: 124,	dt: 6.245ms,	v: 49.3,	Rn: 61.6,	loss: 2,	training_step: 2.92e+04
# [TrainMonitor|INFO] ep: 586,	T: 44,718,	G: 118,	avg_r: 1,	avg_G: 94.7,	t: 118,	dt: 6.891ms,	v: 51.8,	Rn: 61.7,	loss: 1.98,	training_step: 2.93e+04
# [TrainMonitor|INFO] ep: 587,	T: 44,844,	G: 125,	avg_r: 1,	avg_G: 97.7,	t: 125,	dt: 6.206ms,	v: 49.3,	Rn: 60.8,	loss: 2,	training_step: 2.94e+04
# [TrainMonitor|INFO] ep: 588,	T: 44,972,	G: 127,	avg_r: 1,	avg_G: 101,	t: 127,	dt: 6.091ms,	v: 47.9,	Rn: 61,	loss: 2.01,	training_step: 2.94e+04
# [TrainMonitor|INFO] ep: 589,	T: 45,100,	G: 127,	avg_r: 1,	avg_G: 103,	t: 127,	dt: 6.108ms,	v: 48.8,	Rn: 63.4,	loss: 1.99,	training_step: 2.94e+04
# [TrainMonitor|INFO] ep: 590,	T: 45,243,	G: 142,	avg_r: 1,	avg_G: 107,	t: 142,	dt: 5.588ms,	v: 47.6,	Rn: 64.3,	loss: 2.01,	training_step: 2.95e+04
# [TrainMonitor|INFO] ep: 591,	T: 45,368,	G: 124,	avg_r: 1,	avg_G: 109,	t: 124,	dt: 9.821ms,	v: 50,	Rn: 61.3,	loss: 1.99,	training_step: 2.96e+04,	test_G: 124
# [TrainMonitor|INFO] ep: 592,	T: 45,470,	G: 101,	avg_r: 1,	avg_G: 108,	t: 101,	dt: 7.529ms,	v: 56.1,	Rn: 60.8,	loss: 2,	training_step: 2.96e+04
# [TrainMonitor|INFO] ep: 593,	T: 45,485,	G: 14,	avg_r: 1,	avg_G: 98.7,	t: 14,	dt: 51.888ms,	v: 41.7,	Rn: 7.47,	loss: 2.02,	training_step: 2.96e+04
# [TrainMonitor|INFO] ep: 594,	T: 45,620,	G: 134,	avg_r: 1,	avg_G: 102,	t: 134,	dt: 5.994ms,	v: 46.5,	Rn: 61.2,	loss: 2.01,	training_step: 2.97e+04
# [TrainMonitor|INFO] ep: 595,	T: 45,742,	G: 121,	avg_r: 1,	avg_G: 104,	t: 121,	dt: 11.959ms,	v: 51.6,	Rn: 63.6,	loss: 2.01,	training_step: 2.98e+04
# [TrainMonitor|INFO] ep: 610,	T: 47,283,	G: 132,	avg_r: 1,	avg_G: 102,	t: 132,	dt: 6.026ms,	v: 45.6,	Rn: 62.7,	loss: 2,	training_step: 3.05e+04
# [TrainMonitor|INFO] ep: 611,	T: 47,305,	G: 21,	avg_r: 1,	avg_G: 93.9,	t: 21,	dt: 52.641ms,	v: 42.6,	Rn: 10.9,	loss: 2,	training_step: 3.06e+04,	test_G: 103
# [TrainMonitor|INFO] ep: 612,	T: 47,431,	G: 125,	avg_r: 1,	avg_G: 97,	t: 125,	dt: 6.294ms,	v: 50.5,	Rn: 62.1,	loss: 2.01,	training_step: 3.06e+04
# [TrainMonitor|INFO] ep: 613,	T: 47,580,	G: 148,	avg_r: 1,	avg_G: 102,	t: 148,	dt: 6.093ms,	v: 46.6,	Rn: 71.1,	loss: 2.02,	training_step: 3.06e+04
# [TrainMonitor|INFO] ep: 614,	T: 47,718,	G: 137,	avg_r: 1,	avg_G: 106,	t: 137,	dt: 6.037ms,	v: 48.2,	Rn: 63.7,	loss: 2,	training_step: 3.07e+04
# [TrainMonitor|INFO] ep: 615,	T: 47,741,	G: 22,	avg_r: 1,	avg_G: 97.2,	t: 22,	dt: 37.091ms,	v: 42.7,	Rn: 11.4,	loss: 1.99,	training_step: 3.08e+04
# [TrainMonitor|INFO] ep: 616,	T: 47,764,	G: 22,	avg_r: 1,	avg_G: 89.7,	t: 22,	dt: 37.566ms,	v: 48.1,	Rn: 11.4,	loss: 2.01,	training_step: 3.08e+04
# [TrainMonitor|INFO] ep: 617,	T: 47,889,	G: 124,	avg_r: 1,	avg_G: 93.1,	t: 124,	dt: 6.886ms,	v: 50.2,	Rn: 61.3,	loss: 2.01,	training_step: 3.08e+04
# [TrainMonitor|INFO] ep: 618,	T: 48,035,	G: 145,	avg_r: 1,	avg_G: 98.3,	t: 145,	dt: 5.484ms,	v: 45.7,	Rn: 68.2,	loss: 2,	training_step: 3.09e+04
# [TrainMonitor|INFO] ep: 619,	T: 48,190,	G: 154,	avg_r: 1,	avg_G: 104,	t: 154,	dt: 5.237ms,	v: 44.2,	Rn: 70.2,	loss: 1.99,	training_step: 3.1e+04
# [TrainMonitor|INFO] ep: 620,	T: 48,318,	G: 127,	avg_r: 1,	avg_G: 106,	t: 127,	dt: 6.222ms,	v: 49.4,	Rn: 62.8,	loss: 1.98,	training_step: 3.1e+04
# [TrainMonitor|INFO] ep: 621,	T: 48,464,	G: 145,	avg_r: 1,	avg_G: 110,	t: 145,	dt: 8.098ms,	v: 45,	Rn: 66.9,	loss: 1.99,	training_step: 3.1e+04,	test_G: 108
# [TrainMonitor|INFO] ep: 622,	T: 48,587,	G: 122,	avg_r: 1,	avg_G: 111,	t: 122,	dt: 6.372ms,	v: 49.6,	Rn: 60.2,	loss: 1.97,	training_step: 3.11e+04
# [TrainMonitor|INFO] ep: 623,	T: 48,630,	G: 42,	avg_r: 1,	avg_G: 104,	t: 42,	dt: 17.773ms,	v: 27.4,	Rn: 21.2,	loss: 2.01,	training_step: 3.12e+04
# [TrainMonitor|INFO] ep: 624,	T: 48,762,	G: 131,	avg_r: 1,	avg_G: 107,	t: 131,	dt: 6.175ms,	v: 48.7,	Rn: 65.8,	loss: 2.03,	training_step: 3.12e+04
# [TrainMonitor|INFO] ep: 625,	T: 48,776,	G: 13,	avg_r: 1,	avg_G: 97.6,	t: 13,	dt: 64.049ms,	v: 55.7,	Rn: 6.97,	loss: 2,	training_step: 3.12e+04
# [TrainMonitor|INFO] ep: 626,	T: 48,902,	G: 125,	avg_r: 1,	avg_G: 100,	t: 125,	dt: 7.129ms,	v: 49.2,	Rn: 61.1,	loss: 2,	training_step: 3.13e+04
# [TrainMonitor|INFO] ep: 627,	T: 49,055,	G: 152,	avg_r: 1,	avg_G: 106,	t: 152,	dt: 5.829ms,	v: 44.2,	Rn: 67.7,	loss: 1.98,	training_step: 3.14e+04
# [TrainMonitor|INFO] ep: 628,	T: 49,192,	G: 136,	avg_r: 1,	avg_G: 109,	t: 136,	dt: 6.428ms,	v: 49,	Rn: 65.7,	loss: 2,	training_step: 3.14e+04
# [TrainMonitor|INFO] ep: 629,	T: 49,331,	G: 138,	avg_r: 1,	avg_G: 112,	t: 138,	dt: 6.666ms,	v: 48.2,	Rn: 66.3,	loss: 2,	training_step: 3.14e+04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/dustyatom/projects/muax/examples/cartpole.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> gradient_transform = muax.model.optimizer(init_value=0.002, peak_value=0.002, end_value=0.0005, warmup_steps=20000, transition_steps=20000)
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=15'>16</a> model = muax.MuZero(repr_fn, pred_fn, dy_fn, policy='muzero', discount=0.999,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=16'>17</a>                     optimizer=gradient_transform, support_size=support_size)
# ---> <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=18'>19</a> model_path = muax.fit(model, 'CartPole-v1',
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=19'>20</a>                 max_episodes=1000,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=20'>21</a>                 max_training_steps=50000,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=21'>22</a>                 tracer=tracer,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=22'>23</a>                 buffer=buffer,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=23'>24</a>                 k_steps=10,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=24'>25</a>                 sample_per_trajectory=1,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=25'>26</a>                 buffer_warm_up=128,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=26'>27</a>                 num_trajectory=128,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=27'>28</a>                 tensorboard_dir=None,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=28'>29</a>                 save_name='model_params',
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=29'>30</a>                 random_seed=i,
#      <a href='vscode-notebook-cell:/Users/dustyatom/projects/muax/examples/cartpole.ipynb#X15sZmlsZQ%3D%3D?line=30'>31</a>                 log_all_metrics=True)
#
# File ~/projects/muax/muax/train.py:208, in fit(model, env_id, env, test_env, tracer, buffer, max_episodes, test_interval, num_test_episodes, max_training_steps, save_every_n_epochs, num_simulations, k_steps, buffer_warm_up, num_trajectory, sample_per_trajectory, name, tensorboard_dir, model_save_path, save_name, random_seed, temperature_fn, log_all_metrics, num_update_per_episode)
#     206 train_loss = 0
#     207 for _ in range(num_update_per_episode):
# --> 208   transition_batch = buffer.sample(num_trajectory=num_trajectory,
#     209                                     sample_per_trajectory=sample_per_trajectory,
#     210                                     k_steps=k_steps)
#     211   loss_metric = model.update(transition_batch)
#     212   train_loss += loss_metric['loss']
#
# File ~/projects/muax/muax/replay_buffer.py:231, in TrajectoryReplayBuffer.sample(self, batch_size, num_trajectory, k_steps, sample_per_trajectory)
#     227 trajectories = random.choices(self._storage,
#     228                               weights=self._trajectory_weight,
#     229                               k=num_trajectory)
#     230 self._random_state = random.getstate()
# --> 231 batch = list(chain.from_iterable(traj.sample(num_samples=sample_per_trajectory, k_steps=k_steps)
#     232              for traj in trajectories
#     233              ))
#     235 batch = jax.tree_util.tree_transpose(
#     236   outer_treedef=jax.tree_util.tree_structure([0 for i in batch]),
#     237   inner_treedef=jax.tree_util.tree_structure(self.transition_class()),
#     238   pytree_to_transpose=batch)
#     239 batch = self.transition_class(*(np.vstack(v) for v in batch))
#
# File ~/projects/muax/muax/replay_buffer.py:231, in <genexpr>(.0)
#     227 trajectories = random.choices(self._storage,
#     228                               weights=self._trajectory_weight,
#     229                               k=num_trajectory)
#     230 self._random_state = random.getstate()
# --> 231 batch = list(chain.from_iterable(traj.sample(num_samples=sample_per_trajectory, k_steps=k_steps)
#     232              for traj in trajectories
#     233              ))
#     235 batch = jax.tree_util.tree_transpose(
#     236   outer_treedef=jax.tree_util.tree_structure([0 for i in batch]),
#     237   inner_treedef=jax.tree_util.tree_structure(self.transition_class()),
#     238   pytree_to_transpose=batch)
#     239 batch = self.transition_class(*(np.vstack(v) for v in batch))
#
# File ~/projects/muax/muax/replay_buffer.py:92, in Trajectory.sample(self, num_samples, k_steps)
#      90 if len(self) <= k_steps: return []
#      91 max_idx = len(self) - k_steps
# ---> 92 idxes = random.choices(range(max_idx),
#      93                       weights=self._transition_weight[:max_idx],
#      94                       k=num_samples)
#      96 if self.batched_transitions is None:
#      97   self.finalize()
#
# KeyboardInterrupt:

# %%
model_path

# %%
model = muax.MuZero(repr_fn, pred_fn, dy_fn, policy='muzero', discount=discount,
                    optimizer=gradient_transform, support_size=support_size)

model.load(model_path)

# %%
from muax.test import test
env_id = 'CartPole-v1'
test_env = gym.make(env_id, render_mode='rgb_array')
test_key = jax.random.PRNGKey(0)
test(model, test_env, test_key, num_simulations=50, num_test_episodes=100, random_seed=None)

# %%
# %load_ext tensorboard 
# %tensorboard --logdir=tensorboard/cartpole

# %% [markdown]
# # 2. Customize

# %% [markdown]
# ## 2.1 Customize the neural networks

# %% [markdown]
# `muax` uses `haiku` to implement the neural networks. A tutorial for using `haiku` can be found at (link).

# %%
import haiku as hk

class Representation(hk.Module):
  def __init__(self, embedding_dim, name='representation'):
    super().__init__(name=name)

    self.repr_func = hk.Sequential([
        hk.Linear(embedding_dim), 
        # jax.nn.elu,
    ])

  def __call__(self, obs):
    s = self.repr_func(obs)
    s = nn.min_max_normalize(s)
    return s 


class Prediction(hk.Module):
  def __init__(self, num_actions, full_support_size, name='prediction'):
    super().__init__(name=name)        
    
    self.v_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(64), jax.nn.elu,
        hk.Linear(16), jax.nn.elu,
        hk.Linear(full_support_size)
    ])
    self.pi_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(64), jax.nn.elu,
        hk.Linear(16), jax.nn.elu,
        hk.Linear(num_actions)
    ])
  
  def __call__(self, s):
    v = self.v_func(s)
    logits = self.pi_func(s)
    # logits = jax.nn.softmax(logits, axis=-1)
    return v, logits


class Dynamic(hk.Module):
  def __init__(self, embedding_dim, num_actions, full_support_size, name='dynamic'):
    super().__init__(name=name)
    
    self.ns_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(64), jax.nn.elu,
        hk.Linear(16), jax.nn.elu,
        hk.Linear(embedding_dim)
    ])
    self.r_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(64), jax.nn.elu,
        hk.Linear(16), jax.nn.elu,
        hk.Linear(full_support_size)
    ])
    self.cat_func = jax.jit(lambda s, a: 
                            jnp.concatenate([s, jax.nn.one_hot(a, num_actions)],
                                            axis=1)
                            )
  
  def __call__(self, s, a):
    sa = self.cat_func(s, a)
    r = self.r_func(sa)
    ns = self.ns_func(sa)
    ns = nn.min_max_normalize(ns)
    return r, ns


def init_representation_func(representation_module, embedding_dim):
    def representation_func(obs):
      repr_model = representation_module(embedding_dim)
      return repr_model(obs)
    return representation_func
  
def init_prediction_func(prediction_module, num_actions, full_support_size):
  def prediction_func(s):
    pred_model = prediction_module(num_actions, full_support_size)
    return pred_model(s)
  return prediction_func

def init_dynamic_func(dynamic_module, embedding_dim, num_actions, full_support_size):
  def dynamic_func(s, a):
    dy_model = dynamic_module(embedding_dim, num_actions, full_support_size)
    return dy_model(s, a)
  return dynamic_func

# %%
support_size = 10 
embedding_size = 8
full_support_size = int(support_size * 2 + 1)
repr_fn = init_representation_func(Representation, embedding_size)
pred_fn = init_prediction_func(Prediction, 2, full_support_size)
dy_fn = init_dynamic_func(Dynamic, embedding_size, 2, full_support_size)

# %% [markdown]
# ## 2.2 Customize the training loop

# %% [markdown]
# inside the `muax.fit` function, the main structure is a typical RL interacting loop. Reset the env, agent takes an action based on the observation, updated current state until done

# %%
import numpy as np 
from muax import Trajectory

def temperature_fn(max_training_steps, training_steps):
  if training_steps < 0.5 * max_training_steps:
      return 1.0
  elif training_steps < 0.75 * max_training_steps:
      return 0.5
  else:
      return 0.25
  
def test(model, env, key, num_simulations, num_test_episodes=10, random_seed=None):
    total_rewards = np.zeros(num_test_episodes)
    for episode in range(num_test_episodes):
        obs, info = env.reset(seed=random_seed)
        done = False
        episode_reward = 0
        for t in range(env.spec.max_episode_steps):
            key, subkey = jax.random.split(key)
            a = model.act(subkey, obs, 
                          with_pi=False, 
                          with_value=False, 
                          obs_from_batch=False,
                          num_simulations=num_simulations,
                          temperature=0.) # Use deterministic actions during testing
            obs_next, r, done, truncated, info = env.step(a)
            episode_reward += r
            if done or truncated:
                break 
            obs = obs_next 
        
        total_rewards[episode] = episode_reward

    average_test_reward = np.mean(total_rewards)
    return average_test_reward

# %%
from jax import numpy as jnp 

random_seed = 0
discount = 0.997
buffer_warm_up = 64
max_training_steps = 10000
max_episodes = 1000
num_simulations = 50
num_test_episodes = 10
num_trajectory = 32
sample_per_trajectory = 1
k_steps = 10

gradient_transform = muax.model.optimizer(init_value=0.02, peak_value=0.02, end_value=0.002, warmup_steps=5000, transition_steps=5000)
tracer = muax.PNStep(10, discount, 0.5)
buffer = muax.TrajectoryReplayBuffer(500)
model = muax.MuZero(repr_fn, pred_fn, dy_fn, optimizer=gradient_transform, discount=discount)

env_id = 'CartPole-v1'
env = gym.make(env_id, render_mode='rgb_array')
test_env = gym.make(env_id, render_mode='rgb_array')

sample_input = jnp.expand_dims(jnp.zeros(env.observation_space.shape), axis=0)
key = jax.random.PRNGKey(random_seed)
key, test_key, subkey = jax.random.split(key, num=3)
model.init(subkey, sample_input) 

training_step = 0
best_test_G = -float('inf')
max_training_steps_reached = False

# buffer warm up
print('buffer warm up stage...')
while len(buffer) < buffer_warm_up:
  obs, info = env.reset()    
  trajectory = Trajectory()
  temperature = temperature_fn(max_training_steps=max_training_steps, training_steps=training_step)
  for t in range(env.spec.max_episode_steps):
    key, subkey = jax.random.split(key)
    a, pi, v = model.act(subkey, obs, 
                          with_pi=True, 
                          with_value=True, 
                          obs_from_batch=False,
                          num_simulations=num_simulations,
                          temperature=temperature)
    obs_next, r, done, truncated, info = env.step(a)
    # if truncated:
    #   r = 1 / (1 - tracer.gamma)
    tracer.add(obs, a, r, done or truncated, v=v, pi=pi)
    while tracer:
      trans = tracer.pop()
      trajectory.add(trans)
    if done or truncated:
      break 
    obs = obs_next 
  trajectory.finalize()
  if len(trajectory) >= k_steps:
    buffer.add(trajectory, trajectory.batched_transitions.w.mean())
  
print('start training...')
  
for ep in range(max_episodes):
  obs, info = env.reset(seed=random_seed)    
  trajectory = Trajectory()
  temperature = temperature_fn(max_training_steps=max_training_steps, training_steps=training_step)
  for t in range(env.spec.max_episode_steps):
    key, subkey = jax.random.split(key)
    a, pi, v = model.act(subkey, obs, 
                          with_pi=True, 
                          with_value=True, 
                          obs_from_batch=False,
                          num_simulations=num_simulations,
                          temperature=temperature)
    obs_next, r, done, truncated, info = env.step(a)
    # if truncated:
    #   r = 1 / (1 - tracer.gamma)
    tracer.add(obs, a, r, done or truncated, v=v, pi=pi)
    while tracer:
      trans = tracer.pop()
      trajectory.add(trans)
    if done or truncated:
      break 
    obs = obs_next 
  trajectory.finalize()
  if len(trajectory) >= k_steps:
    buffer.add(trajectory, trajectory.batched_transitions.w.mean())
  
  if max_training_steps_reached:
    break
  train_loss = 0
  for _ in range(50):
    transition_batch = buffer.sample(num_trajectory=num_trajectory,
                                      sample_per_trajectory=sample_per_trajectory,
                                      k_steps=k_steps)
    loss_metric = model.update(transition_batch)
    train_loss += loss_metric['loss']
    training_step += 1
    if training_step >= max_training_steps:
      max_training_steps_reached = True
      break
  train_loss /= 50
  print(f'epoch: {ep:04d}, loss: {train_loss:.8f}, training_step: {training_step}')

  test_G = test(model, test_env, test_key, num_simulations=num_simulations, num_test_episodes=num_test_episodes)      
  print(f'epoch: {ep:04d}, test_G: {test_G:.8f}')
  if test_G >= best_test_G:
    best_test_G = test_G

print(f'Best total reward in test: {best_test_G}')
